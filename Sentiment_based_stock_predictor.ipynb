# %% [markdown]
# ## Project setup
#
# ### Step 1
# Load the data. You need to create a folder in your google drive called dataset and upload the csv file. Rename it to finance.csv
# ### Step 2
# Train the neural network,
# ### Step 3
# Use this map in the testing phase to determine how a news article will affect a given stock

# %% [markdown]
# ### **Step 1.1 Loading the dataset**

# %%
import sys
print(sys.version)
# Out:
# 3.11.14 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 18:30:03) [MSC v.1929 64 bit (AMD64)]

# %%
# for colab users uncomment the following lines to mount your google drive
#from google.colab import drive
# drive.mount('/content/drive')

# %%
#! pip install lightning > /dev/null
#! pip install tokenizers > /dev/null
#! pip install pandas > /dev/null
# ! pip install lightning
# ! pip install tokenizers
import pandas as pd
#glbl_ds_pth = "/content/drive/MyDrive/dataset" # for colab users
file_path = "finance.csv" #TODO: 
print(f"Loading data from: {file_path}")
df = pd.read_csv(file_path, encoding="ISO-8859-1")
print(f"📊 Original data shape: {df.shape}")
# Out:
# Loading data from: finance.csv
# 📊 Original data shape: (602248, 24)

# %%
#! python --version

# %% [markdown]
# ### **Step 1.2 make headlines lowercase + special character removal**

# %%
# SCRAPPED for FINbert
#
# import string
# # This section makes the words easier to work with
# cleaner = str.maketrans('', '', string.punctuation)

# df['news_article'] = df['news_article'].apply(lambda x: x.translate(cleaner).lower())
# print(f"📊 Original data shape: {df.shape}")

# %% [markdown]
# ### Step 1.3 Add daily price change

# %%
def calculate_score(row):
    close_price = row['close_price']
    open_price = row['open_price']
    percent_diff = (close_price - open_price) / open_price
    if percent_diff > 0.02:
        return 5
    elif percent_diff > 0.005:
        return 4
    elif percent_diff > -0.005:
        return 3
    elif percent_diff > -0.02:
        return 2
    else:
        return 1
   


    #return round(percent_diff * 100, 3)

for index, row in df.iterrows():
    score = calculate_score(row)
    df.at[index, 'price_change'] = score

# Count how many rows belong to each class
class_counts = df["price_change"].value_counts().sort_index()

print("Price Change Class Counts:")
print(class_counts)

#print(df["price_change"])
# Out:
# Price Change Class Counts:
# price_change
# 1.0    113917
# 2.0    116029
# 3.0    135805
# 4.0    123292
# 5.0    113205
# Name: count, dtype: int64

# %% [markdown]
# ### Step 1.4: Extract sentiment and embeddings from FINbert

# %%
# %pip install tqdm transformers torch
import torch
torch.cuda.is_available()
# Out:
# Requirement already satisfied: tqdm in c:\users\goali\anaconda3\envs\py311\lib\site-packages (4.67.1)
# Requirement already satisfied: transformers in c:\users\goali\anaconda3\envs\py311\lib\site-packages (4.57.3)
# Requirement already satisfied: torch in c:\users\goali\anaconda3\envs\py311\lib\site-packages (2.9.1+cpu)
# Requirement already satisfied: colorama in c:\users\goali\anaconda3\envs\py311\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: filelock in c:\users\goali\anaconda3\envs\py311\lib\site-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\goali\anaconda3\envs\py311\lib\site-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\goali\anaconda3\envs\py311\lib\site-packages (from transformers) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\goali\anaconda3\envs\py311\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\goali\anaconda3\envs\py311\lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\goali\anaconda3\envs\py311\lib\site-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in c:\users\goali\anaconda3\envs\py311\lib\site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\goali\anaconda3\envs\py311\lib\site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\goali\anaconda3\envs\py311\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\goali\anaconda3\envs\py311\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\goali\anaconda3\envs\py311\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\goali\anaconda3\envs\py311\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\goali\anaconda3\envs\py311\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\goali\anaconda3\envs\py311\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\goali\anaconda3\envs\py311\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\goali\anaconda3\envs\py311\lib\site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\goali\anaconda3\envs\py311\lib\site-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\goali\anaconda3\envs\py311\lib\site-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\goali\anaconda3\envs\py311\lib\site-packages (from requests->transformers) (2.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\goali\anaconda3\envs\py311\lib\site-packages (from requests->transformers) (2025.11.12)
# Note: you may need to restart the kernel to use updated packages.
# False

# %%
import torch.nn.functional as F
from sklearn.decomposition import PCA
import numpy as np
from tqdm import tqdm
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import pandas as pd

# FinBERT sentiment model
model_name = "ProsusAI/finbert"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name, output_hidden_states=False)

#put on GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()

# Clean Data Set
class HeadLineDataset(Dataset):
  def __init__(self, texts):
    self.texts = texts

  def __len__(self):
    return len(self.texts)

  def __getitem__(self, idx):
    return self.texts[idx]

def collate_fn(batch):
    enc = tokenizer(
        batch,
        padding=True,
        truncation=True,
        max_length=512,
        return_tensors="pt"
    )
    return batch, enc

print("🚀 Starting FinBERT processing...")

batch_size = 32
dataset = HeadLineDataset(df["news_article"].tolist())
loader = DataLoader(
    dataset,
    batch_size=batch_size,
    collate_fn=collate_fn
)

all_sentiments = []
all_embeddings = []

print(f" Processing {len(dataset)} headlines in batches of {batch_size}...")

# Batch Processing Loop
for texts, inputs in tqdm(loader, desc="Processing FinBERT"):
  inputs = {k: v.to(device) for k, v in inputs.items()}

  with torch.no_grad():
    # Get sentiment probabilities
    outputs = model(**inputs)
    probs = F.softmax(outputs.logits, dim=-1).cpu().numpy()
    all_sentiments.extend(probs)

    # Get embeddings from base model
    base_outputs = model.bert(**inputs)
    cls_vectors = base_outputs.last_hidden_state[:, 0, :].cpu().numpy()
    all_embeddings.extend(cls_vectors)

    #   CRITICAL: Store original indices for each processed row
    # all_original_indices.extend(indices)

print("📊 Compressing embeddings with PCA...")
all_embeddings_array = np.array(all_embeddings)
pca = PCA(n_components=128)
reduced_embeddings = pca.fit_transform(all_embeddings_array)

print(f" Compression complete! Retained {np.sum(pca.explained_variance_ratio_):.2%} variance")

finbert_df = pd.DataFrame()

# finbert_df['original_index'] = all_original_indices

# Add sentiment probabilities (3 columns)
finbert_df[['sent_neg', 'sent_neu', 'sent_pos']] = all_sentiments

# Add all embeddings (128 columns)
for i in range(128):
  finbert_df[f'finbert_emb_{i}'] = reduced_embeddings[:, i]

# VERIFICATION: Check alignment
print("\n VERIFICATION REPORT:")
print(f"   Original dataset rows: {len(df)}")
print(f"   Processed features rows: {len(finbert_df)}")
print(f"   Rows filtered out: {len(df) - len(finbert_df)}")

print("🎉 PROCESSING COMPLETE!")
print(f"    Final shape: {finbert_df.shape}")
print(f"    Columns: {len(finbert_df.columns)} (3 sentiments + 128 embeddings)")
# Out:
# 🚀 Starting FinBERT processing...
#  Processing 602248 headlines in batches of 32...
# Processing FinBERT:   0%|          | 1/18821 [00:03<16:52:04,  3.23s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 63
#      59 inputs = {k: v.to(device) for k, v in inputs.items()}
#      61 with torch.no_grad():
#      62   # Get sentiment probabilities
# ---> 63   outputs = model(**inputs)
#      64   probs = F.softmax(outputs.logits, dim=-1).cpu().numpy()
#      65   all_sentiments.extend(probs)
#
# File c:\Users\goali\anaconda3\envs\py311\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\goali\anaconda3\envs\py311\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\goali\anaconda3\envs\py311\Lib\site-packages\transformers\models\bert\modeling_bert.py:1482, in BertForSequenceClassification.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1474 r"""
#    1475 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#    1476     Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#    1477     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#    1478     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#    1479 """
#    1480 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1482 outputs = self.bert(
#    1483     input_ids,
#    1484     attention_mask=attention_mask,
#    1485     token_type_ids=token_type_ids,
#    1486     position_ids=position_ids,
#    1487     head_mask=head_mask,
#    1488     inputs_embeds=inputs_embeds,
#    1489     output_attentions=output_attentions,
#    1490     output_hidden_states=output_hidden_states,
#    1491     return_dict=return_dict,
#    1492 )
#    1494 pooled_output = outputs[1]
#    1496 pooled_output = self.dropout(pooled_output)
#
# File c:\Users\goali\anaconda3\envs\py311\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\goali\anaconda3\envs\py311\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\goali\anaconda3\envs\py311\Lib\site-packages\transformers\models\bert\modeling_bert.py:1000, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     993 # Prepare head mask if needed
#     994 # 1.0 in head_mask indicate we keep the head
#     995 # attention_probs has shape bsz x n_heads x N x N
#     996 # input head_mask has shape [num_heads] or [num_hidden_layers x num_heads]
#     997 # and head_mask is converted to shape [num_hidden_layers x batch x num_heads x seq_length x seq_length]
#     998 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# -> 1000 encoder_outputs = self.encoder(
#    1001     embedding_output,
#    1002     attention_mask=extended_attention_mask,
#    1003     head_mask=head_mask,
#    1004     encoder_hidden_states=encoder_hidden_states,
#    1005     encoder_attention_mask=encoder_extended_attention_mask,
#    1006     past_key_values=past_key_values,
#    1007     use_cache=use_cache,
#    1008     output_attentions=output_attentions,
#    1009     output_hidden_states=output_hidden_states,
#    1010     return_dict=return_dict,
#    1011     cache_position=cache_position,
#    1012 )
#    1013 sequence_output = encoder_outputs[0]
#    1014 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File c:\Users\goali\anaconda3\envs\py311\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\goali\anaconda3\envs\py311\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\goali\anaconda3\envs\py311\Lib\site-packages\transformers\models\bert\modeling_bert.py:650, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     646     all_hidden_states = all_hidden_states + (hidden_states,)
#     648 layer_head_mask = head_mask[i] if head_mask is not None else None
# --> 650 layer_outputs = layer_module(
#     651     hidden_states,
#     652     attention_mask,
#     653     layer_head_mask,
#     654     encoder_hidden_states,  # as a positional argument for gradient checkpointing
#     655     encoder_attention_mask=encoder_attention_mask,
#     656     past_key_values=past_key_values,
#     657     output_attentions=output_attentions,
#     658     cache_position=cache_position,
#     659 )
#     661 hidden_states = layer_outputs[0]
#     662 if output_attentions:
#
# File c:\Users\goali\anaconda3\envs\py311\Lib\site-packages\transformers\modeling_layers.py:94, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      91         logger.warning_once(message)
#      93     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 94 return super().__call__(*args, **kwargs)
#
# File c:\Users\goali\anaconda3\envs\py311\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\goali\anaconda3\envs\py311\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\goali\anaconda3\envs\py311\Lib\site-packages\transformers\utils\deprecation.py:172, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     168 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS) and not is_torchdynamo_compiling():
#     169     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     170     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 172 return func(*args, **kwargs)
#
# File c:\Users\goali\anaconda3\envs\py311\Lib\site-packages\transformers\models\bert\modeling_bert.py:588, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, output_attentions, cache_position)
#     585     attention_output = cross_attention_outputs[0]
#     586     outputs = outputs + cross_attention_outputs[1:]  # add cross attentions if we output attention weights
# --> 588 layer_output = apply_chunking_to_forward(
#     589     self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     590 )
#     591 outputs = (layer_output,) + outputs
#     593 return outputs
#
# File c:\Users\goali\anaconda3\envs\py311\Lib\site-packages\transformers\pytorch_utils.py:257, in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     254     # concatenate output at same dimension
#     255     return torch.cat(output_chunks, dim=chunk_dim)
# --> 257 return forward_fn(*input_tensors)
#
# File c:\Users\goali\anaconda3\envs\py311\Lib\site-packages\transformers\models\bert\modeling_bert.py:597, in BertLayer.feed_forward_chunk(self, attention_output)
#     595 def feed_forward_chunk(self, attention_output):
#     596     intermediate_output = self.intermediate(attention_output)
# --> 597     layer_output = self.output(intermediate_output, attention_output)
#     598     return layer_output
#
# File c:\Users\goali\anaconda3\envs\py311\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\goali\anaconda3\envs\py311\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\goali\anaconda3\envs\py311\Lib\site-packages\transformers\models\bert\modeling_bert.py:525, in BertOutput.forward(self, hidden_states, input_tensor)
#     524 def forward(self, hidden_states: torch.Tensor, input_tensor: torch.Tensor) -> torch.Tensor:
# --> 525     hidden_states = self.dense(hidden_states)
#     526     hidden_states = self.dropout(hidden_states)
#     527     hidden_states = self.LayerNorm(hidden_states + input_tensor)
#
# File c:\Users\goali\anaconda3\envs\py311\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\goali\anaconda3\envs\py311\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\goali\anaconda3\envs\py311\Lib\site-packages\torch\nn\modules\linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
print("🔍 SAMPLING KEY COLUMNS:")
print("=" * 50)

# finbert_df = pd.read_parquet(f"{glbl_ds_pth}/finbert_features.parquet") # USED TO SKIP ABOVE STEP, REMOVE WHEN FINISHED
# finbert_df = (finbert_df
#     .drop('original_index', axis=1)
#     .rename(columns=lambda x: x.replace('emb_', 'finbert_emb_') if x.startswith('emb_') else x)
# )
# # Reorder columns: embeddings first, then sentiments
# embedding_cols = [col for col in finbert_df.columns if 'finbert_emb_' in col]
# sentiment_cols = ['sent_neg', 'sent_neu', 'sent_pos']
# other_cols = [col for col in finbert_df.columns if col not in embedding_cols + sentiment_cols]

# finbert_df = finbert_df[other_cols + sentiment_cols + embedding_cols]

# Show original_index + sentiments + first 5 embeddings
sample_cols = ['sent_neg', 'sent_neu', 'sent_pos']
sample_cols.extend([f'finbert_emb_{i}' for i in range(5)])  # First 5 embeddings

print(finbert_df[sample_cols].head(-10).round(3))  # Round to 3 decimal places
# Out:
# 🔍 SAMPLING KEY COLUMNS:
# ==================================================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 20
#      17 sample_cols = ['sent_neg', 'sent_neu', 'sent_pos']
#      18 sample_cols.extend([f'finbert_emb_{i}' for i in range(5)])  # First 5 embeddings
# ---> 20 print(finbert_df[sample_cols].head(-10).round(3))  # Round to 3 decimal places
#
# NameError: name 'finbert_df' is not defined

# %%
print(f"📊 Original data shape: {df.shape}")

# Your FinBERT features (already loaded as features_df)
print(f"📈 FinBERT features shape: {finbert_df.shape}")
# Out:
# 📊 Original data shape: (602248, 159)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 4
#       1 print(f"📊 Original data shape: {df.shape}")
#       3 # Your FinBERT features (already loaded as features_df)
# ----> 4 print(f"📈 FinBERT features shape: {finbert_df.shape}")
#
# NameError: name 'finbert_df' is not defined

# %% [markdown]
# ### 1.5: getting numerics of categories

# %%
from sklearn.preprocessing import LabelEncoder
import json
import os

def debug_label_encoded_csvs():
    """
    Debug version with extensive error handling
    """
    print("🐛 DEBUG MODE: Starting label encoding...")


    # Load your data
    try:
        print(f" First few rows:")
        print(df[['stock_name', 'sector', 'industry']].head(2))
    except Exception as e:
        print(f" Failed to load CSV: {e}")
        return

    # Categorical columns to encode
    categorical_columns = ['stock_name', 'sector', 'industry']

    # Check if columns exist
    print(f"\n🔍 CHECKING COLUMNS:")
    for col in categorical_columns:
        exists = col in df.columns
        print(f"   {col}: {' EXISTS' if exists else ' MISSING'}")
        if exists:
            print(f"      dtype: {df[col].dtype}")
            print(f"      non-null: {df[col].notna().sum()}/{len(df)}")
            print(f"      sample: {df[col].iloc[:3].tolist()}")

    # Store encoders and results
    encoders = {}
    results = {}

    for col in categorical_columns:
        if col in df.columns:
            print(f"\n🎯 Processing {col}...")

            try:
                # Check for null values
                null_count = df[col].isnull().sum()
                if null_count > 0:
                    print(f"    Warning: {null_count} null values in {col}")
                    # Fill nulls with a placeholder
                    df[col] = df[col].fillna('UNKNOWN')

                # Create label encoder
                encoder = LabelEncoder()
                encoded_values = encoder.fit_transform(df[col])
                print(f"    Label encoding successful")

                # Create DataFrame for this category
                encoded_df = pd.DataFrame({
                    'original_index': df.index,
                    f'{col}_encoded': encoded_values
                })
                print(f"    DataFrame created: {encoded_df.shape}")

                # Store encoder info
                encoders[col] = {
                    'encoder': encoder,
                    'classes': encoder.classes_.tolist(),
                    'num_classes': len(encoder.classes_)
                }

                results[col] = {
                    'shape': encoded_df.shape,
                    'num_classes': len(encoder.classes_)
                }

                print(f"    Unique values: {len(encoder.classes_)}")
                print(f"    Sample mapping: {encoder.classes_[:3]} → [0, 1, 2]")

            except Exception as e:
                print(f"    Error processing {col}: {e}")
                import traceback
                traceback.print_exc()
                continue

    # Save encoder mappings to JSON
    if encoders:
        try:
            encoder_info = {}
            for col, info in encoders.items():
                encoder_info[col] = {
                    'num_classes': info['num_classes'],
                    'classes_sample': info['classes'][:10]
                }

            encoder_file = f"label_encoder_mappings.json"
            with open(encoder_file, 'w') as f:
                json.dump(encoder_info, f, indent=2)

            print(f"\n Encoder mappings saved to: {encoder_file}")
            print(f" JSON file exists: {os.path.exists(encoder_file)}")

        except Exception as e:
            print(f" Failed to save JSON: {e}")
    else:
        print(" No encoders created - skipping JSON save")

    # Create merged version
    try:
        print(f"\n🔄 Creating merged dataset...")
        merged_df = df.copy()
        print(f" Merged base shape: {merged_df.shape}")

        for col in categorical_columns:
            if col in df.columns and col in encoders:
                merged_df[f'{col}_encoded'] = encoders[col]['encoder'].transform(df[col])

        # Drop original categorical columns
        #merged_df = pd.concat([merged_df_, finbert_df], axis=1) uncomment this 

        merged_file = "finance.csv"
        merged_df.to_csv(merged_file, index=False)

        print(f" Merged dataset saved to: {merged_file}")
        print(f" Merged shape: {merged_df.shape}")
        print(f" Merged file exists: {os.path.exists(merged_file)}")

    except Exception as e:
        print(f" Failed to create merged dataset: {e}")
        merged_df = None

    # List all files in output directory
    print(f"\n FILES IN OUTPUT DIRECTORY:")
    try:
        files = os.listdir(".")
        if files:
            for file in files:
                file_path = os.path.join(".", file)
                file_size = os.path.getsize(file_path)
                print(f"    {file} ({file_size} bytes)")
        else:
            print("   ❌ No files found!")
    except Exception as e:
        print(f"   ❌ Could not list directory: {e}")

    return results, encoders, merged_df

# %% [markdown]
# ### 1.6: getting numerics of categories

# %%
# Run the debug version
print("STARTING DEBUG LABEL ENCODING...")
results, encoders, merged_df = debug_label_encoded_csvs()
# Out:
# STARTING DEBUG LABEL ENCODING...
# 🐛 DEBUG MODE: Starting label encoding...
#  First few rows:
#   stock_name  sector             industry
# 0       TOPS  Energy  Oil & Gas Midstream
# 1       TOPS  Energy  Oil & Gas Midstream
#
# 🔍 CHECKING COLUMNS:
#    stock_name:  EXISTS
#       dtype: object
#       non-null: 602248/602248
#       sample: ['TOPS', 'TOPS', 'TOPS']
#    sector:  EXISTS
#       dtype: object
#       non-null: 133088/602248
#       sample: ['Energy', 'Energy', 'Energy']
#    industry:  EXISTS
#       dtype: object
#       non-null: 133088/602248
#       sample: ['Oil & Gas Midstream', 'Oil & Gas Midstream', 'Oil & Gas Midstream']
#
# 🎯 Processing stock_name...
#     Label encoding successful
#     DataFrame created: (602248, 2)
#     Unique values: 2437
#     Sample mapping: ['AAN' 'AAOI' 'AAP'] → [0, 1, 2]
#
# 🎯 Processing sector...
#     Warning: 469160 null values in sector
#     Label encoding successful
#     DataFrame created: (602248, 2)
#     Unique values: 12
#     Sample mapping: ['Basic Materials' 'Communication Services' 'Consumer Cyclical'] → [0, 1, 2]
#
# 🎯 Processing industry...
#     Warning: 469160 null values in industry
#     Label encoding successful
#     DataFrame created: (602248, 2)
#     Unique values: 60
#     Sample mapping: ['Advertising Agencies' 'Aerospace & Defense' 'Agricultural Inputs'] → [0, 1, 2]
#
#  Encoder mappings saved to: label_encoder_mappings.json
#  JSON file exists: True
#
# 🔄 Creating merged dataset...
#  Merged base shape: (602248, 25)
#  Merged dataset saved to: finance.csv
#  Merged shape: (602248, 28)
#  Merged file exists: True
#
#  FILES IN OUTPUT DIRECTORY:
#     .git (4096 bytes)
#     after_fin_finance.csv (1052783796 bytes)
#     finance.csv (170610171 bytes)
#     label_encoder_mappings.json (917 bytes)
#     README.md (56 bytes)
#     scaler.pkl (6735 bytes)
#     Sentiment_based_stock_predictor.ipynb (189749 bytes)

# %% [markdown]
# ## This section allows you to use a precreated merged_df
# Please use this to avoid heavy finBERT computation, after_fin_finance.csv contains its output and is the merged_df from above

# %%
import pandas as pd
merged_df = pd.read_csv("after_fin_finance.csv", encoding="ISO-8859-1")

def calculate_score(row):
    close_price = row['close_price']
    open_price = row['open_price']
    percent_diff = (close_price - open_price) / open_price
    if percent_diff > 0.02:
        return 5
    elif percent_diff > 0.005:
        return 4
    elif percent_diff > -0.005:
        return 3
    elif percent_diff > -0.02:
        return 2
    else:
        return 1
   

for index, row in merged_df.iterrows():
    score = calculate_score(row)
    merged_df.at[index, 'price_change'] = score

# Count how many rows belong to each class
class_counts = merged_df["price_change"].value_counts().sort_index()

print("Price Change Class Counts:") # verify even distribution
print(class_counts)
# Out:
# Price Change Class Counts:
# price_change
# 1.0    113917
# 2.0    116029
# 3.0    135805
# 4.0    123292
# 5.0    113205
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

scale_columns = [
    'volume',                    # Millions/billions
    'open_price', 'high_price', 'low_price', 'close_price',  # Dollar values
    'float_shares',              # Large numbers
    'shares_outstanding',        # Very large numbers
    'market_cap',                # Billions/trillions
    'pe_ratio',                  # Can be 0-100+ range
    'daily_volatility_pct'       # Percentages but can vary widely
]
optional_scale = [
    #'signed_price_move_pct', using this is leakage
    'sent_neg', 'sent_neu', 'sent_pos', 'has_fda', 'has_merger','has_upgrade', 'has_downgrade'

]
total_scale = scale_columns + optional_scale


# Split data first (important!)
train_df, val_df = train_test_split(merged_df, test_size=0.3, random_state=42)

scalar = StandardScaler()
train_df[total_scale] = scalar.fit_transform(train_df[total_scale])
val_df[total_scale] = scalar.transform(val_df[total_scale])

print(f"\n📈 Scaled {len(total_scale)} features to mean=0, std=1")
print(f"   train_df shape: {train_df.shape}")
print(f"   val_df shape: {val_df.shape}")
print(f"   train_df columns: {train_df.columns}")
print(f"   val_df columns: {val_df.columns}")
print(f"   train_df head: {train_df.head(2)}")
print(f"   val_df head: {val_df.head(2)}")
# Out:
# 📈 Scaled 17 features to mean=0, std=1
#    train_df shape: (421573, 159)
#    val_df shape: (180675, 159)
#    train_df columns: Index(['date_only', 'news_article', 'stock_name', 'volume', 'open_price',
#        'high_price', 'low_price', 'close_price', 'signed_price_move_pct',
#        'move_category',
#        ...
#        'finbert_emb_118', 'finbert_emb_119', 'finbert_emb_120',
#        'finbert_emb_121', 'finbert_emb_122', 'finbert_emb_123',
#        'finbert_emb_124', 'finbert_emb_125', 'finbert_emb_126',
#        'finbert_emb_127'],
#       dtype='object', length=159)
#    val_df columns: Index(['date_only', 'news_article', 'stock_name', 'volume', 'open_price',
#        'high_price', 'low_price', 'close_price', 'signed_price_move_pct',
#        'move_category',
#        ...
#        'finbert_emb_118', 'finbert_emb_119', 'finbert_emb_120',
#        'finbert_emb_121', 'finbert_emb_122', 'finbert_emb_123',
#        'finbert_emb_124', 'finbert_emb_125', 'finbert_emb_126',
#        'finbert_emb_127'],
#       dtype='object', length=159)
#    train_df head:          date_only                                       news_article  \
# 304757  2010-04-16                       Top Stocks of North Carolina
# 335017  2018-11-13  A Peek Into The Markets: US Stock Futures Sign...
#
#        stock_name    volume  open_price  high_price  low_price  close_price  \
# 304757        DUK -0.306774   -0.048804   -0.037332  -0.046235    -0.043494
# 335017        AAP -0.339787    0.398557    0.279050   0.381713     0.345491
#
#         signed_price_move_pct move_category  ...  finbert_emb_118  \
# 304757               0.309985          Flat  ...        -0.027786
# 335017               0.776874          Flat  ...        -0.307612
#
#         finbert_emb_119  finbert_emb_120  finbert_emb_121  finbert_emb_122  \
# 304757        -0.008432         0.477411        -0.334283         0.357300
# 335017         0.788396         0.105860        -0.004343        -0.477682
#
#         finbert_emb_123  finbert_emb_124  finbert_emb_125  finbert_emb_126  \
# 304757         0.159542         0.051870        -0.592075         0.125983
# 335017        -0.074187        -0.027984        -0.372880         0.164539
#
#         finbert_emb_127
# 304757        -0.475919
# 335017        -0.302256
#
# [2 rows x 159 columns]
#    val_df head:          date_only                                       news_article  \
# 321356  2016-11-16  UPDATE: First Solar Announces Series 4 Product...
# 41437   2013-12-20                   Benzinga's Top #PreMarket Losers
#
#        stock_name    volume  open_price  high_price  low_price  close_price  \
# 321356       FSLR -0.325495   -0.099448    -0.07293  -0.098180    -0.086778
# 41437        GOLD  1.035746   -0.153258    -0.11056  -0.150157    -0.132993
#
#         signed_price_move_pct move_category  ...  finbert_emb_118  \
# 321356               0.302762          Flat  ...        -0.218282
# 41437                0.777984          Flat  ...        -0.020600
#
#         finbert_emb_119  finbert_emb_120  finbert_emb_121  finbert_emb_122  \
# 321356        -0.041937         0.056054         1.063124        -0.769082
# 41437         -0.324622         0.009016        -0.296266        -0.161205
#
#         finbert_emb_123  finbert_emb_124  finbert_emb_125  finbert_emb_126  \
# 321356        -0.742489         0.178141         0.052322        -0.248546
# 41437          0.011749        -0.182669         0.157467         0.091882
#
#         finbert_emb_127
# 321356        -0.339815
# 41437         -0.480536
#
# [2 rows x 159 columns]

# %% [markdown]
# # Training Loop

# %% [markdown]
# ## Prepare DataLoaders

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import classification_report, confusion_matrix

# Make sure we're using GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# ---- 1. Define which columns to use as features ----

# FinBERT embedding columns (if present)
embedding_cols = [f"finbert_emb_{i}" for i in range(128) if f"finbert_emb_{i}" in train_df.columns]

# Sentiment columns
sent_cols = ["sent_neg", "sent_neu", "sent_pos"]

# Encoded categorical columns
cat_cols = ["stock_name_encoded", "sector_encoded", "industry_encoded"]

# Numeric columns you already scaled earlier
num_cols = total_scale  # from your previous code

# Final feature list
feature_cols = embedding_cols + sent_cols + cat_cols + num_cols
#leak_features = ["signed_price_move_pct"] not using to begin with
deployment_features = [col for col in feature_cols]
print("Number of features:", len(feature_cols))
print("price_change in feature_cols?", "price_change" in feature_cols)

# ---- 2. Clean NaNs just in case ----
target_col = "price_change"

train_df_m = train_df.dropna(subset=feature_cols + [target_col]).copy()
val_df_m   = val_df.dropna(subset=feature_cols + [target_col]).copy()

# ---- 3. Numpy arrays for X and y ----
X_train = train_df_m[feature_cols].values.astype("float32")
X_val   = val_df_m[feature_cols].values.astype("float32")

# price_change is in {1,2,3,4,5}; CrossEntropyLoss expects class indices 0..(C-1). Looks like there are no 1's in price change to create the zero, causing 4 to be out of bounds.
y_train = train_df_m[target_col].values.astype("int64") - 1
y_val   = val_df_m[target_col].values.astype("int64") - 1

num_classes = len(np.unique(y_train))
print("Classes:", np.unique(y_train), "→ num_classes =", num_classes)

# ---- 4. Torch Dataset wrappers ----
class FinanceDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.from_numpy(X)       # float32
        self.y = torch.from_numpy(y)       # int64
    def __len__(self):
        return len(self.X)
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

train_dataset = FinanceDataset(X_train, y_train)
val_dataset   = FinanceDataset(X_val, y_val)

#atch_size = 128

train_loader = DataLoader(train_dataset, batch_size=2048, shuffle=True, drop_last=False)
val_loader   = DataLoader(val_dataset, batch_size=2048, shuffle=False, drop_last=False)


# Or check for any negative values after transformation
negative_mask = y_train < 0
if negative_mask.any():
    print(f"Warning: Found {negative_mask.sum()} negative values in y_train")
    print("Negative values:", y_train[negative_mask])
# Out:
# Using device: cpu
# Number of features: 151
# price_change in feature_cols? False
# Classes: [0 1 2 3 4] → num_classes = 5

# %% [markdown]
# ## Implement MLP

# %%
class MLPClassifier(nn.Module):
    def __init__(self, input_dim, num_classes):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Dropout(0.3),

            nn.Linear(256, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.3),

            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        return self.net(x)


input_dim = X_train.shape[1]
model = MLPClassifier(input_dim=input_dim, num_classes=num_classes).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=3e-4, weight_decay=1e-2)

# %% [markdown]
# ## Training loop + validation

# %%
epochs = 50

for epoch in range(1, epochs + 1):
    # ---- Train ----
    model.train()
    running_loss = 0.0
    running_conf = 0.0


    for batch_X, batch_y in train_loader:
        batch_X = batch_X.to(device)
        batch_y = batch_y.to(device)

        optimizer.zero_grad()
        logits = model(batch_X)              # shape: (batch, num_classes)

        loss = criterion(logits, batch_y) # problem here
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * batch_X.size(0)

        probs = torch.softmax(logits, dim=1)
        max_probs, preds = torch.max(probs, dim=1) # Correctly get max probabilities (confidence) and indices (predictions)
        running_conf += max_probs.sum().item()             # sum of confidences

    epoch_train_loss = running_loss / len(train_dataset)
    epoch_train_conf = running_conf / len(train_dataset)



    # ---- Validate ----
    model.eval()
    val_loss = 0.0
    all_preds = []
    all_true = []
    val_conf_sum = 0.0 # Initialize val_conf_sum for the validation loop

    with torch.no_grad():
        for batch_X, batch_y in val_loader:
            batch_X = batch_X.to(device)
            batch_y = batch_y.to(device)

            logits = model(batch_X)
            loss = criterion(logits, batch_y)
            val_loss += loss.item() * batch_X.size(0)


            probs = torch.softmax(logits, dim=1)
            max_probs, preds = torch.max(probs, dim=1) # Correctly get max probabilities (confidence) and indices (predictions)

            val_conf_sum += max_probs.sum().item()      # Use max_probs for sum of confidences

            all_preds.extend(preds.cpu().numpy())
            all_true.extend(batch_y.cpu().numpy())

    epoch_val_loss = val_loss / len(val_dataset)
    epoch_val_conf = val_conf_sum / len(val_dataset)      # avg val confidence

    accuracy = (np.array(all_preds) == np.array(all_true)).mean()

    print(
        f"Epoch {epoch:02d} | "
        f"Train Loss: {epoch_train_loss:.4f} | "
        f"Val Loss: {epoch_val_loss:.4f} | "
        f"Val Acc: {accuracy:.4f} | "
        f"Train Conf: {epoch_train_conf:.3f} | "
        f"Val Conf: {epoch_val_conf:.3f}"
    )
# Out:
# Epoch 01 | Train Loss: 1.6239 | Val Loss: 1.5647 | Val Acc: 0.2698 | Train Conf: 0.299 | Val Conf: 0.280
# Epoch 02 | Train Loss: 1.5798 | Val Loss: 1.5496 | Val Acc: 0.2850 | Train Conf: 0.309 | Val Conf: 0.274
# Epoch 03 | Train Loss: 1.5587 | Val Loss: 1.5355 | Val Acc: 0.2907 | Train Conf: 0.311 | Val Conf: 0.301
# Epoch 04 | Train Loss: 1.5383 | Val Loss: 1.5181 | Val Acc: 0.2991 | Train Conf: 0.316 | Val Conf: 0.304
# Epoch 05 | Train Loss: 1.5195 | Val Loss: 1.4944 | Val Acc: 0.3167 | Train Conf: 0.322 | Val Conf: 0.311
# Epoch 06 | Train Loss: 1.4984 | Val Loss: 1.4880 | Val Acc: 0.3185 | Train Conf: 0.328 | Val Conf: 0.299
# Epoch 07 | Train Loss: 1.4805 | Val Loss: 1.4996 | Val Acc: 0.3175 | Train Conf: 0.332 | Val Conf: 0.281
# Epoch 08 | Train Loss: 1.4673 | Val Loss: 1.4529 | Val Acc: 0.3350 | Train Conf: 0.336 | Val Conf: 0.330
# Epoch 09 | Train Loss: 1.4509 | Val Loss: 1.4395 | Val Acc: 0.3428 | Train Conf: 0.341 | Val Conf: 0.316
# Epoch 10 | Train Loss: 1.4382 | Val Loss: 1.4242 | Val Acc: 0.3496 | Train Conf: 0.346 | Val Conf: 0.318
# Epoch 11 | Train Loss: 1.4238 | Val Loss: 1.4129 | Val Acc: 0.3540 | Train Conf: 0.348 | Val Conf: 0.323
# Epoch 12 | Train Loss: 1.4120 | Val Loss: 1.4162 | Val Acc: 0.3471 | Train Conf: 0.352 | Val Conf: 0.348
# Epoch 13 | Train Loss: 1.4012 | Val Loss: 1.4788 | Val Acc: 0.3100 | Train Conf: 0.357 | Val Conf: 0.318
# Epoch 14 | Train Loss: 1.3882 | Val Loss: 1.4081 | Val Acc: 0.3477 | Train Conf: 0.359 | Val Conf: 0.335
# Epoch 15 | Train Loss: 1.3752 | Val Loss: 1.4148 | Val Acc: 0.3507 | Train Conf: 0.363 | Val Conf: 0.401
# Epoch 16 | Train Loss: 1.3679 | Val Loss: 1.3591 | Val Acc: 0.3753 | Train Conf: 0.366 | Val Conf: 0.338
# Epoch 17 | Train Loss: 1.3560 | Val Loss: 1.3413 | Val Acc: 0.3894 | Train Conf: 0.371 | Val Conf: 0.338
# Epoch 18 | Train Loss: 1.3438 | Val Loss: 1.3284 | Val Acc: 0.3829 | Train Conf: 0.374 | Val Conf: 0.366
# Epoch 19 | Train Loss: 1.3392 | Val Loss: 1.3518 | Val Acc: 0.3772 | Train Conf: 0.378 | Val Conf: 0.398
# Epoch 20 | Train Loss: 1.3309 | Val Loss: 1.3491 | Val Acc: 0.3701 | Train Conf: 0.377 | Val Conf: 0.388
# Epoch 21 | Train Loss: 1.3264 | Val Loss: 1.4415 | Val Acc: 0.3599 | Train Conf: 0.383 | Val Conf: 0.453
# Epoch 22 | Train Loss: 1.3154 | Val Loss: 1.3904 | Val Acc: 0.3546 | Train Conf: 0.388 | Val Conf: 0.332
# Epoch 23 | Train Loss: 1.3066 | Val Loss: 1.3989 | Val Acc: 0.3680 | Train Conf: 0.387 | Val Conf: 0.451
# Epoch 24 | Train Loss: 1.3015 | Val Loss: 1.2796 | Val Acc: 0.4025 | Train Conf: 0.397 | Val Conf: 0.382
# Epoch 25 | Train Loss: 1.3025 | Val Loss: 1.3239 | Val Acc: 0.3953 | Train Conf: 0.395 | Val Conf: 0.339
# Epoch 26 | Train Loss: 1.2868 | Val Loss: 1.2751 | Val Acc: 0.4020 | Train Conf: 0.399 | Val Conf: 0.402
# Epoch 27 | Train Loss: 1.2804 | Val Loss: 1.2674 | Val Acc: 0.4102 | Train Conf: 0.400 | Val Conf: 0.392
# Epoch 28 | Train Loss: 1.3000 | Val Loss: 1.3453 | Val Acc: 0.3849 | Train Conf: 0.402 | Val Conf: 0.447
# Epoch 29 | Train Loss: 1.2765 | Val Loss: 1.2681 | Val Acc: 0.4153 | Train Conf: 0.401 | Val Conf: 0.374
# Epoch 30 | Train Loss: 1.2695 | Val Loss: 1.2557 | Val Acc: 0.4100 | Train Conf: 0.409 | Val Conf: 0.399
# Epoch 31 | Train Loss: 1.2675 | Val Loss: 1.2672 | Val Acc: 0.4061 | Train Conf: 0.409 | Val Conf: 0.398
# Epoch 32 | Train Loss: 1.2639 | Val Loss: 1.2758 | Val Acc: 0.4068 | Train Conf: 0.410 | Val Conf: 0.399
# Epoch 33 | Train Loss: 1.2640 | Val Loss: 1.4443 | Val Acc: 0.3042 | Train Conf: 0.415 | Val Conf: 0.355
# Epoch 34 | Train Loss: 1.2618 | Val Loss: 1.3045 | Val Acc: 0.3931 | Train Conf: 0.411 | Val Conf: 0.451
# Epoch 35 | Train Loss: 1.2527 | Val Loss: 1.2876 | Val Acc: 0.4144 | Train Conf: 0.417 | Val Conf: 0.369
# Epoch 36 | Train Loss: 1.2531 | Val Loss: 1.2457 | Val Acc: 0.4179 | Train Conf: 0.417 | Val Conf: 0.411
# Epoch 37 | Train Loss: 1.2521 | Val Loss: 1.2460 | Val Acc: 0.4163 | Train Conf: 0.417 | Val Conf: 0.402
# Epoch 38 | Train Loss: 1.2580 | Val Loss: 1.2647 | Val Acc: 0.4182 | Train Conf: 0.418 | Val Conf: 0.372
# Epoch 39 | Train Loss: 1.2602 | Val Loss: 1.2623 | Val Acc: 0.4093 | Train Conf: 0.415 | Val Conf: 0.425
# Epoch 40 | Train Loss: 1.2466 | Val Loss: 1.2950 | Val Acc: 0.4015 | Train Conf: 0.422 | Val Conf: 0.457
# Epoch 41 | Train Loss: 1.2520 | Val Loss: 1.2392 | Val Acc: 0.4192 | Train Conf: 0.420 | Val Conf: 0.405
# Epoch 42 | Train Loss: 1.2449 | Val Loss: 1.2530 | Val Acc: 0.4241 | Train Conf: 0.422 | Val Conf: 0.386
# Epoch 43 | Train Loss: 1.2479 | Val Loss: 1.2632 | Val Acc: 0.4067 | Train Conf: 0.422 | Val Conf: 0.443
# Epoch 44 | Train Loss: 1.2462 | Val Loss: 1.3185 | Val Acc: 0.3924 | Train Conf: 0.419 | Val Conf: 0.370
# Epoch 45 | Train Loss: 1.2493 | Val Loss: 1.3145 | Val Acc: 0.3972 | Train Conf: 0.423 | Val Conf: 0.465
# Epoch 46 | Train Loss: 1.2394 | Val Loss: 1.2629 | Val Acc: 0.4137 | Train Conf: 0.424 | Val Conf: 0.409
# Epoch 47 | Train Loss: 1.2390 | Val Loss: 1.2673 | Val Acc: 0.4106 | Train Conf: 0.426 | Val Conf: 0.452
# Epoch 48 | Train Loss: 1.2444 | Val Loss: 1.2367 | Val Acc: 0.4214 | Train Conf: 0.426 | Val Conf: 0.415
# Epoch 49 | Train Loss: 1.2364 | Val Loss: 1.2540 | Val Acc: 0.4115 | Train Conf: 0.425 | Val Conf: 0.440
# Epoch 50 | Train Loss: 1.2338 | Val Loss: 1.2352 | Val Acc: 0.4230 | Train Conf: 0.428 | Val Conf: 0.408

# %% [markdown]
# ## Evaluate

# %%
# ---- 7. Final evaluation: classification report & confusion matrix ----
print("\nClassification report (classes 0–4 correspond to original price_change 1–5):")
print(classification_report(all_true, all_preds, digits=4))

print("Confusion matrix:")
print(confusion_matrix(all_true, all_preds))
# Out:
# Classification report (classes 0–4 correspond to original price_change 1–5):
#               precision    recall  f1-score   support
#
#            0     0.4166    0.4692    0.4413      5034
#            1     0.3235    0.2279    0.2674      7715
#            2     0.5645    0.6013    0.5824      9665
#            3     0.3576    0.3855    0.3710      8346
#            4     0.3943    0.4243    0.4088      4798
#
#     accuracy                         0.4270     35558
#    macro avg     0.4113    0.4216    0.4142     35558
# weighted avg     0.4198    0.4270    0.4210     35558
#
# Confusion matrix:
# [[2362  559    0  541 1572]
#  [ 740 1758 2095 2559  563]
#  [ 383 1127 5812 2031  312]
#  [ 535 1526 2387 3217  681]
#  [1650  464    1  647 2036]]

# %% [markdown]
# ## Deployment

# %%
import random
import numpy as np
import torch
import pandas as pd

def deployment_demo(model, df, deployment_features, num_examples=5):
    """
    Deployment-style demo using the SAME feature space as training.
    Assumes `df` already has features in the same transformed form as X_train/X_val.
    """
    print("🚀 REAL-WORLD DEPLOYMENT DEMONSTRATION")
    print("Using ONLY information available when news breaks")
    print("=" * 60)

    # Reset index to avoid weird index behavior
    df = df.reset_index(drop=True)

    model.eval()
    results = []

    # 5-class mapping (your categories)
    categories = {
        1: "Small Down",
        2: "Medium Down",
        3: "Neutral",
        4: "Medium Up",
        5: "Large Up"
    }

    for i in range(num_examples):
        idx = random.randint(0, len(df) - 1)
        row = df.iloc[idx]

        print(f"\n📰 EXAMPLE {i+1}:")
        print(f"Headline: {row['news_article'][:120]}...")
        print(f"Company: {row.get('stock_name', 'N/A')}")

        # Build feature vector in the SAME order as during training
        X = row[deployment_features].values.astype("float32").reshape(1, -1)

        # No extra scaling here – df is already in model's feature space
        X_tensor = torch.from_numpy(X).to(device)

        with torch.no_grad():
            logits = model(X_tensor)
            probs = torch.softmax(logits, dim=1)
            confidence, pred_idx = torch.max(probs, dim=1)

            # y_train = price_change - 1, so:
            # model outputs 0..4 -> add 1 to get back 1..5
            predicted_pc = int(pred_idx.item()) + 1
            actual_pc = int(row["price_change"])

        print(f"🤖 PREDICTION (made at news time):")
        print(f"  Category: {categories.get(predicted_pc, predicted_pc)}")
        print(f"  Confidence: {confidence.item():.1%}")

        print(f"🎯 ACTUAL RESULT (unknown at prediction time):")
        print(f"  Actual Category: {categories.get(actual_pc, actual_pc)}")

        if "signed_price_move_pct" in row.index:
            print(f"  Actual % Move: {row['signed_price_move_pct']:.2f}%")

        is_correct = (predicted_pc == actual_pc)
        print(f"📊 RESULT: {'✅ CORRECT' if is_correct else '❌ INCORRECT'}")

        results.append(is_correct)

    print(f"\n{'=' * 60}")
    accuracy = sum(results) / len(results)
    print("Deployment Model Performance (sampled from val set):")
    print(f"  Demo Accuracy: {accuracy:.1%} ({sum(results)}/{len(results)} correct)")
    print("\n💡 This shows how the model would behave on new headlines in a live setting.")


deployment_demo(model, val_df_m, deployment_features, num_examples=30)
# Out:
# 🚀 REAL-WORLD DEPLOYMENT DEMONSTRATION
# Using ONLY information available when news breaks
# ============================================================
#
# 📰 EXAMPLE 1:
# Headline: Birth Control Stocks: A Recession Play...
# Company: MRK
# 🤖 PREDICTION (made at news time):
#   Category: Medium Up
#   Confidence: 39.7%
# 🎯 ACTUAL RESULT (unknown at prediction time):
#   Actual Category: Medium Up
#   Actual % Move: 1.39%
# 📊 RESULT: ✅ CORRECT
#
# 📰 EXAMPLE 2:
# Headline: Market Drift  12-27-2010...
# Company: WMB
# 🤖 PREDICTION (made at news time):
#   Category: Neutral
#   Confidence: 46.6%
# 🎯 ACTUAL RESULT (unknown at prediction time):
#   Actual Category: Neutral
#   Actual % Move: 0.53%
# 📊 RESULT: ✅ CORRECT
#
# 📰 EXAMPLE 3:
# Headline: US Big Pharma: What To Watch For In Q4 Results...
# Company: LLY
# 🤖 PREDICTION (made at news time):
#   Category: Medium Up
#   Confidence: 42.6%
# 🎯 ACTUAL RESULT (unknown at prediction time):
#   Actual Category: Medium Down
#   Actual % Move: 0.85%
# 📊 RESULT: ❌ INCORRECT
#
# 📰 EXAMPLE 4:
# Headline: 'Ford plans to reopen some plants soon, but workers are worried about coronavirus' -Recent CNN Article...
# Company: F
# 🤖 PREDICTION (made at news time):
#   Category: Small Down
#   Confidence: 49.5%
# 🎯 ACTUAL RESULT (unknown at prediction time):
#   Actual Category: Small Down
#   Actual % Move: 5.41%
# 📊 RESULT: ✅ CORRECT
#
# 📰 EXAMPLE 5:
# Headline: Jim Cramer Weighs In On Shopify, Sirius XM And National Retail Properties...
# Company: SIRI
# 🤖 PREDICTION (made at news time):
#   Category: Medium Up
#   Confidence: 35.9%
# 🎯 ACTUAL RESULT (unknown at prediction time):
#   Actual Category: Neutral
#   Actual % Move: 1.41%
# 📊 RESULT: ❌ INCORRECT
#
# 📰 EXAMPLE 6:
# Headline: Market Roundup (CSX, BRK.A, RIMM, SPG, GGP, BAM, FNM, FRE, POT, MOS)...
# Company: MOS
# 🤖 PREDICTION (made at news time):
#   Category: Medium Up
#   Confidence: 29.5%
# 🎯 ACTUAL RESULT (unknown at prediction time):
#   Actual Category: Neutral
#   Actual % Move: 0.79%
# 📊 RESULT: ❌ INCORRECT
#
# 📰 EXAMPLE 7:
# Headline: Late Market Roundup...
# Company: MRK
# 🤖 PREDICTION (made at news time):
#   Category: Medium Up
#   Confidence: 35.7%
# 🎯 ACTUAL RESULT (unknown at prediction time):
#   Actual Category: Neutral
#   Actual % Move: 1.51%
# 📊 RESULT: ❌ INCORRECT
#
# 📰 EXAMPLE 8:
# Headline: Berenberg Initiates Coverage On Infosys Limited American Depositary Shares with Sell Rating, Announces $14.00 Price Targ...
# Company: INFY
# 🤖 PREDICTION (made at news time):
#   Category: Neutral
#   Confidence: 48.0%
# 🎯 ACTUAL RESULT (unknown at prediction time):
#   Actual Category: Medium Down
#   Actual % Move: 0.06%
# 📊 RESULT: ❌ INCORRECT
#
# 📰 EXAMPLE 9:
# Headline: Stocks Get China Boost From Second China Disneyland Loan...
# Company: VALE
# 🤖 PREDICTION (made at news time):
#   Category: Medium Up
#   Confidence: 38.4%
# 🎯 ACTUAL RESULT (unknown at prediction time):
#   Actual Category: Medium Up
#   Actual % Move: 1.99%
# 📊 RESULT: ✅ CORRECT
#
# 📰 EXAMPLE 10:
# Headline: 10 Stocks To Watch For November 3, 2017...
# Company: SBUX
# 🤖 PREDICTION (made at news time):
#   Category: Large Up
#   Confidence: 30.0%
# 🎯 ACTUAL RESULT (unknown at prediction time):
#   Actual Category: Large Up
#   Actual % Move: 5.13%
# 📊 RESULT: ✅ CORRECT
#
# 📰 EXAMPLE 11:
# Headline: Stocks That Hit 52-Week Lows On Wednesday...
# Company: UAL
# 🤖 PREDICTION (made at news time):
#   Category: Small Down
#   Confidence: 52.6%
# 🎯 ACTUAL RESULT (unknown at prediction time):
#   Actual Category: Small Down
#   Actual % Move: 0.56%
# 📊 RESULT: ✅ CORRECT
#
# 📰 EXAMPLE 12:
# Headline: Credit Suisse Upgrading SLM Corp....
# Company: SLM
# 🤖 PREDICTION (made at news time):
#   Category: Medium Up
#   Confidence: 24.3%
# 🎯 ACTUAL RESULT (unknown at prediction time):
#   Actual Category: Small Down
#   Actual % Move: 0.00%
# 📊 RESULT: ❌ INCORRECT
#
# 📰 EXAMPLE 13:
# Headline: ETFs: Focusing On Financials In February...
# Company: WFC
# 🤖 PREDICTION (made at news time):
#   Category: Neutral
#   Confidence: 35.5%
# 🎯 ACTUAL RESULT (unknown at prediction time):
#   Actual Category: Medium Up
#   Actual % Move: 1.27%
# 📊 RESULT: ❌ INCORRECT
#
# 📰 EXAMPLE 14:
# Headline: Pre-Market Imbalance Update: Alibaba 278K Shares To Buy, BofA 111K Shares To Sell, Merck 85K To Buy, GE 8.5K To Buy...
# Company: MRK
# 🤖 PREDICTION (made at news time):
#   Category: Neutral
#   Confidence: 60.6%
# 🎯 ACTUAL RESULT (unknown at prediction time):
#   Actual Category: Neutral
#   Actual % Move: 0.16%
# 📊 RESULT: ✅ CORRECT
#
# 📰 EXAMPLE 15:
# Headline: Airline Stocks Lower Premarket Wed., Likely Related To Crude Oil Rising Over $70/Barrel: American Down 1.2%, United Down...
# Company: UAL
# 🤖 PREDICTION (made at news time):
#   Category: Medium Down
#   Confidence: 28.8%
# 🎯 ACTUAL RESULT (unknown at prediction time):
#   Actual Category: Small Down
#   Actual % Move: 0.46%
# 📊 RESULT: ❌ INCORRECT
#
# 📰 EXAMPLE 16:
# Headline: J.P. Morgan Maintains Overweight on Coca-Cola...
# Company: KO
# 🤖 PREDICTION (made at news time):
#   Category: Neutral
#   Confidence: 40.4%
# 🎯 ACTUAL RESULT (unknown at prediction time):
#   Actual Category: Neutral
#   Actual % Move: 0.52%
# 📊 RESULT: ✅ CORRECT
#
# 📰 EXAMPLE 17:
# Headline: Goldman Sachs Initiates Coverage On Medtronic with Sell Rating, Announces $118 Price Target...
# Company: MDT
# 🤖 PREDICTION (made at news time):
#   Category: Medium Up
#   Confidence: 26.1%
# 🎯 ACTUAL RESULT (unknown at prediction time):
#   Actual Category: Medium Up
#   Actual % Move: 2.18%
# 📊 RESULT: ✅ CORRECT
#
# 📰 EXAMPLE 18:
# Headline: Gilead Says Odds Of Improvement In Clinical Status With 10-day Course Of Remdesivir Were Trending Toward But Not Reachin...
# Company: GILD
# 🤖 PREDICTION (made at news time):
#   Category: Medium Down
#   Confidence: 27.9%
# 🎯 ACTUAL RESULT (unknown at prediction time):
#   Actual Category: Neutral
#   Actual % Move: 1.89%
# 📊 RESULT: ❌ INCORRECT
#
# 📰 EXAMPLE 19:
# Headline: UPDATE: Jefferies Raises PT on MasterCard on Closing Valuation Gap...
# Company: MA
# 🤖 PREDICTION (made at news time):
#   Category: Medium Up
#   Confidence: 34.8%
# 🎯 ACTUAL RESULT (unknown at prediction time):
#   Actual Category: Medium Down
#   Actual % Move: 0.82%
# 📊 RESULT: ❌ INCORRECT
#
# 📰 EXAMPLE 20:
# Headline: Stocks To Watch For September 3, 2013...
# Company: VZ
# 🤖 PREDICTION (made at news time):
#   Category: Medium Down
#   Confidence: 33.6%
# 🎯 ACTUAL RESULT (unknown at prediction time):
#   Actual Category: Medium Up
#   Actual % Move: 2.04%
# 📊 RESULT: ❌ INCORRECT
#
# 📰 EXAMPLE 21:
# Headline: Morgan Stanley Maintains Overweight on Coca-Cola, Raises Price Target to $61...
# Company: KO
# 🤖 PREDICTION (made at news time):
#   Category: Neutral
#   Confidence: 53.4%
# 🎯 ACTUAL RESULT (unknown at prediction time):
#   Actual Category: Medium Up
#   Actual % Move: 0.70%
# 📊 RESULT: ❌ INCORRECT
#
# 📰 EXAMPLE 22:
# Headline: Benzinga's Top Upgrades...
# Company: WU
# 🤖 PREDICTION (made at news time):
#   Category: Medium Up
#   Confidence: 33.8%
# 🎯 ACTUAL RESULT (unknown at prediction time):
#   Actual Category: Neutral
#   Actual % Move: 1.28%
# 📊 RESULT: ❌ INCORRECT
#
# 📰 EXAMPLE 23:
# Headline: Mosaic Rallies on Q1 Earnings Results...
# Company: MOS
# 🤖 PREDICTION (made at news time):
#   Category: Large Up
#   Confidence: 39.9%
# 🎯 ACTUAL RESULT (unknown at prediction time):
#   Actual Category: Small Down
#   Actual % Move: 0.00%
# 📊 RESULT: ❌ INCORRECT
#
# 📰 EXAMPLE 24:
# Headline: Barclays Maintains Equal-Weight on Cisco Systems, Lowers Price Target to $47...
# Company: CSCO
# 🤖 PREDICTION (made at news time):
#   Category: Medium Down
#   Confidence: 37.0%
# 🎯 ACTUAL RESULT (unknown at prediction time):
#   Actual Category: Medium Down
#   Actual % Move: 0.97%
# 📊 RESULT: ✅ CORRECT
#
# 📰 EXAMPLE 25:
# Headline: As Tech Dividends Rise, ETF Outpaces Some Key Holdings...
# Company: VZ
# 🤖 PREDICTION (made at news time):
#   Category: Neutral
#   Confidence: 55.6%
# 🎯 ACTUAL RESULT (unknown at prediction time):
#   Actual Category: Neutral
#   Actual % Move: 0.06%
# 📊 RESULT: ✅ CORRECT
#
# 📰 EXAMPLE 26:
# Headline: Five Stocks for the Day After the End of the World...
# Company: CCL
# 🤖 PREDICTION (made at news time):
#   Category: Medium Down
#   Confidence: 34.5%
# 🎯 ACTUAL RESULT (unknown at prediction time):
#   Actual Category: Medium Up
#   Actual % Move: 1.05%
# 📊 RESULT: ❌ INCORRECT
#
# 📰 EXAMPLE 27:
# Headline: Option Alert: $FCX Oct $11 Call Call Sweep; 1194 Contracts @Ask @$0.90; Now $11.70...
# Company: FCX
# 🤖 PREDICTION (made at news time):
#   Category: Large Up
#   Confidence: 42.9%
# 🎯 ACTUAL RESULT (unknown at prediction time):
#   Actual Category: Large Up
#   Actual % Move: 4.37%
# 📊 RESULT: ✅ CORRECT
#
# 📰 EXAMPLE 28:
# Headline: Wells Fargo's Hateful 8: Shares Are Down 8 Sessions In A Row, Worst Streak In 8 Years...
# Company: WFC
# 🤖 PREDICTION (made at news time):
#   Category: Neutral
#   Confidence: 43.4%
# 🎯 ACTUAL RESULT (unknown at prediction time):
#   Actual Category: Medium Down
#   Actual % Move: 0.32%
# 📊 RESULT: ❌ INCORRECT
#
# 📰 EXAMPLE 29:
# Headline: Benzinga Market Primer: Wednesday, August 28: Possibility Of Military Action In Syria Puts A Damper On Markets...
# Company: CCL
# 🤖 PREDICTION (made at news time):
#   Category: Neutral
#   Confidence: 56.9%
# 🎯 ACTUAL RESULT (unknown at prediction time):
#   Actual Category: Medium Down
#   Actual % Move: 0.00%
# 📊 RESULT: ❌ INCORRECT
#
# 📰 EXAMPLE 30:
# Headline: The Market In 5 Minutes: Sometimes It Snows In April...
# Company: CCL
# 🤖 PREDICTION (made at news time):
#   Category: Small Down
#   Confidence: 36.6%
# 🎯 ACTUAL RESULT (unknown at prediction time):
#   Actual Category: Medium Down
#   Actual % Move: 1.81%
# 📊 RESULT: ❌ INCORRECT
#
# ============================================================
# Deployment Model Performance (sampled from val set):
#   Demo Accuracy: 40.0% (12/30 correct)
#
# 💡 This shows how the model would behave on new headlines in a live setting.
